# %% [markdown]
# ## PYTHON VARIABLE AND DATA TYPE

# %% [markdown]
# > ## Variable
# >
# > Variables are containers for storing data values.
# >
# > Python has no command for declaring a variable. A variable is created the moment you first assign a value to it.

# %%
x = 5
y = 10+1
z = "Hello World"

# %%
# Manggil variable
x
# Out:
# 5

# %%
print(y)
# Out:
# 11

# %%
z
# Out:
# 'Hello World'

# %%
# calling horizontally
x, y, z
# Out:
# (5, 11, 'Hello World')

# %%
print(x,y,z)
# Out:
# 5 11 Hello World

# %%
# replace variable with new variable
x = "this is x"

# %%
print(x)
# Out:
# this is x

# %% [markdown]
# > ## Variable Names
# >
# >A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume). Rules for Python variables:
# >
# >A variable name must start with a letter or the underscore character
# >
# >A variable name cannot start with a number
# >
# >A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# >
# >Variable names are case-sensitive (age, Age and AGE are three different variables)
# >
# >A variable name cannot be any of the [Python keywords](https://www.w3schools.com/python/python_ref_keywords.asp)
# >
# >we can delete variable using `del()`.

# %%
# creating variable with diffrent naming
myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"

# %%
print(_my_var)
# Out:
# John

# %%
var_a = "Hello World"
print(var_a)
# Out:
# Hello World

# %%
del(var_a)

# %%
# printing deleted variable will return an error
# print(var_a)

# %%
# assign multiple values to variable
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
# assign one value to mutiple variable
x = y = z ="Apple"
print(x)
print(y)
print(z)
# Out:
# Apple
# Apple
# Apple

# %%
# unpacking list
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# >## Data Type
# >
# >![image.png](attachment:e7e55105-867b-42fd-8e70-6b4fe929cc10.png)
# >
# >Python provides several built-in data types that are readily available for use without requiring additional libraries or modules. These have defined structures, attributes, and behaviors specific to your problem domain.

# %%
# numeric type
num_int = 15 #integer
num_float = 7.0 #float
num_comp = 5j #complex

# %%
# string type
text_str = "This is string" # anything within the quote mark (' ')

# %%
#boolean type
boolean1 = True
boolean2 = False

# %%
print(type(int))
print(type(text_str))
print(type(boolean1))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# > ### Bulit-in Data Type (Structure)
# >Python provides several built-in data types that are readily available for use without requiring additional libraries or modules. These have defined structures, attributes, and behaviors specific to your problem domain.
# >
# >Python has the following data types built-in by default, in these categories:
# >
# >1.Text Type:	str
# >
# >2.Numeric Types:	int, float, complex
# >
# >3.Sequence Types:	list, tuple, range
# >
# >4.Mapping Type:	dict
# >
# >5.Set Types:	set, frozenset
# >
# >6.Boolean Type:	bool
# >
# >7.Binary Types:	bytes, bytearray, memoryview
# >
# >8.None Type:	NoneType

# %%
# list type
list1=[1,2.12,3.77,"four",5] #[]
list2=["one","two","three"]

# %%
# print list
print(list1)
print(type(list1))
# Out:
# [1, 2.12, 3.77, 'four', 5]
# <class 'list'>

# %%
# tuple type
tup1 = (1,2.12,3.77,"four",5) #()
tup2 = ("one","two","three")

# %%
# print tuple
print(tup1)
print(type(tup2))
# Out:
# (1, 2.12, 3.77, 'four', 5)
# <class 'tuple'>

# %%
#set type
set1 = {1,2.12,3.77,"four",5} #{}
set2 = {"one","two","three"}

# %%
# print set
print(set1)
print(type(set2))
# Out:
# {1, 2.12, 3.77, 5, 'four'}
# <class 'set'>

# %%
# dictionary type
dict1 = {"first_name":"Bambang",
         "last_name":"Pamungkas",
         "age": 43} # using {key : value}

# %%
#print dictionary
print(dict1)
print(type(dict1))
# Out:
# {'first_name': 'Bambang', 'last_name': 'Pamungkas', 'age': 43}
# <class 'dict'>

# %% [markdown]
# ## REFERENCE
# >https://www.w3schools.com/python/python_datatypes.asp
# >
# >https://siddp6.medium.com/python-programming-language-part-3-6-ab0af8000e27
